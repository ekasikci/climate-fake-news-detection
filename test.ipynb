# %%
import json
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import torch.nn.functional as F

saved_model_path = "./climate_fever_model"  
model = AutoModelForSequenceClassification.from_pretrained(saved_model_path)
tokenizer = AutoTokenizer.from_pretrained(saved_model_path)

label_map = {
    "SUPPORTS": "SUPPORTS",
    "REFUTES": "REFUTES",
    "NOT_ENOUGH_INFO": "UNDECIDED",
    "DISPUTED": "UNDECIDED"
}
label_mapping = ['SUPPORTS', 'REFUTES', 'UNDECIDED']  
label_to_index = {label: idx for idx, label in enumerate(label_mapping)} 

def predict_label_with_probs(claim):
    features = tokenizer(
        [claim], 
        padding='max_length', 
        truncation=True, 
        return_tensors="pt", 
        max_length=512
    )
    
    model.eval()
    with torch.no_grad():
        scores = model(**features).logits
        probs = F.softmax(scores, dim=-1)  
        predicted_label_idx = probs.argmax(dim=1).item()
        predicted_label = label_mapping[predicted_label_idx]
        probabilities = probs[0].tolist() 
    
    
    return predicted_label

dataset_path = "dataset\\fr_climate-fever-dataset-r1_period_maj_opus-mt-tc-big-en-fr_v2-unicode.jsonl"
true_labels = []
predicted_labels = []

with open(dataset_path, "r", encoding="utf-8") as file:
    for line in file:
        data = json.loads(line)
        claim = data["claim"]
        claim_label = data["claim_label"]
        
        if claim_label == 'DISPUTED':
            continue
        
        mapped_claim_label = label_map.get(claim_label, "neutral")  # Default to 'neutral' if label not found
        
        predicted_label = predict_label_with_probs(claim)
        
        print(f"predicted_label: {predicted_label}")
        true_labels.append(label_to_index[mapped_claim_label])
        predicted_labels.append(label_to_index[predicted_label])

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted')  # Weighted average for multiclass
recall = recall_score(true_labels, predicted_labels, average='weighted')  # Weighted average for multiclass
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Weighted average for multiclass

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (weighted): {precision:.4f}")
print(f"Recall (weighted): {recall:.4f}")
print(f"F1 Score (weighted): {f1:.4f}")
# Out:
# Claim: Le réchauffement climatique pousse les ours polaires vers l’extinction.
# Probabilities: [0.1859290599822998, 0.42708903551101685, 0.38698193430900574]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le soleil est entré dans un «verrouillage» qui pourrait provoquer un temps glacial, des tremblements de terre et la famine, disent les scientifiques.
# Probabilities: [0.17503845691680908, 0.43944552540779114, 0.38551604747772217]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La population d'ours polaires a augmenté.
# Probabilities: [0.18599869310855865, 0.42838168144226074, 0.3856196403503418]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Une étude ironique révèle que plus de CO2 a légèrement refroidi la planète.
# Probabilities: [0.18654797971248627, 0.427424818277359, 0.38602718710899353]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les ajouts humains de CO2 se situent dans la marge d’erreur des mesures actuelles et l’augmentation progressive du CO2 provient principalement du dégazage des océans alors que la planète émerge lentement de la dernière période glaciaire.
# Probabilities: [0.1796427220106125, 0.4351806342601776, 0.3851766586303711]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ils nous disent que nous sommes les principales forces contrôlant la température de la terre par la combustion de combustibles fossiles et en libérant leur dioxyde de carbone.
# Probabilities: [0.17290134727954865, 0.4407684803009033, 0.38633015751838684]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La Grande Barrière de Corail connaît le blanchiment le plus répandu jamais enregistré.
# Probabilities: [0.18615207076072693, 0.4272140562534332, 0.38663381338119507]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ce n’est pas un polluant qui menace la civilisation humaine.
# Probabilities: [0.22487807273864746, 0.38703644275665283, 0.38808542490005493]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Si le CO2 était si terrible pour la planète, l’installation d’un générateur de CO2 dans une serre tuerait les plantes.
# Probabilities: [0.18071278929710388, 0.433702677488327, 0.3855844736099243]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'élévation du niveau de la mer a été lente et constante, avant l'industrialisation.
# Probabilities: [0.18711920082569122, 0.42495080828666687, 0.3879300057888031]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La Terre est sur le point d’entrer dans la «mini-ère glaciaire» de 30 ans.
# Probabilities: [0.18732482194900513, 0.42646607756614685, 0.386209100484848]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les volcans fondent dans les glaciers de l'Antarctique occidental, pas le réchauffement climatique.
# Probabilities: [0.2189299762248993, 0.39415979385375977, 0.38691025972366333]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les feux de brousse [en Australie] ont été causés par des incendiaires et une série de coups de foudre, pas par le «changement climatique».
# Probabilities: [0.21423357725143433, 0.39964017271995544, 0.38612622022628784]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La découverte des émissions massives de CO2 volcaniques discrédite la théorie du réchauffement climatique.
# Probabilities: [0.18432626128196716, 0.42862412333488464, 0.38704952597618103]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Une étude de Harvard révèle que les éoliennes génèrent plus de réchauffement climatique que les combustibles fossiles qu’elles éliminent.
# Probabilities: [0.1814798265695572, 0.430740088224411, 0.3877800703048706]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les icebergs fondent, le niveau de l’océan reste le même.
# Probabilities: [0.18418815732002258, 0.4291088581085205, 0.3867030143737793]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Quand exactement le même groupe d'experts qui prétendait que c'était un refroidissement global en 1977 prétend maintenant que c'est le réchauffement climatique, vous pouvez facilement voir pourquoi je suis sceptique.
# Probabilities: [0.18597008287906647, 0.42510470747947693, 0.3889252841472626]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les scientifiques qui étudient la glace de mer de l'Antarctique préviennent qu'une augmentation de l'accumulation pourrait déclencher la prochaine période glaciaire.
# Probabilities: [0.17946180701255798, 0.4338759183883667, 0.3866623044013977]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Plus de 500 scientifiques et professionnels du climat et des domaines connexes ont envoyé une «Déclaration européenne sur le climat» au Secrétaire général des Nations Unies.
# Probabilities: [0.1774483621120453, 0.4364183247089386, 0.38613325357437134]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Un changement climatique sans précédent a fait monter le niveau de la mer au port de Sydney d'environ 0,0 cm au cours des 140 dernières années.
# Probabilities: [0.1886170208454132, 0.4238474369049072, 0.3875354826450348]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le carbone produit par l’homme pourrait être l’un des facteurs [du changement climatique], mais il n’y a tout simplement aucune preuve qu’il soit important.
# Probabilities: [0.21631388366222382, 0.3930698037147522, 0.3906163275241852]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le CO2 ne provoque pas de changement climatique, il y répond [...]
# Probabilities: [0.22146043181419373, 0.3869427442550659, 0.39159682393074036]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: La température moyenne de la Terre au cours des 2000 dernières années montre deux périodes précédentes où les températures étaient plus chaudes qu'elles ne le sont maintenant; de 1 à 200 après JC, une époque appelée la période chaude romaine, et plus récemment la période chaude médiévale de 900 à 1100 après JC.
# Probabilities: [0.19637659192085266, 0.413366436958313, 0.3902569115161896]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: [La NASA] a ajusté les températures du passé [...]
# Probabilities: [0.18532398343086243, 0.4257403016090393, 0.38893577456474304]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il y a cinquante-cinq mille ans, le monde entier était 2 ° C plus chaud qu’aujourd’hui.
# Probabilities: [0.19930414855480194, 0.4120907485485077, 0.3886052072048187]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’élévation du niveau de la mer n’aura pas lieu.
# Probabilities: [0.22832834720611572, 0.38531431555747986, 0.3863573670387268]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Le temps froid pour saisir le monde comme minimum solaire pour approfondir, dit la NASA.
# Probabilities: [0.1833842545747757, 0.43017593026161194, 0.38643980026245117]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’un des glaciers qui se rétrécissait le plus rapidement au monde se développe à nouveau, remettant en question le récit selon lequel le changement climatique rapide [...].
# Probabilities: [0.18131884932518005, 0.4312421679496765, 0.38743898272514343]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les modèles prédisaient environ trois fois la quantité de réchauffement dans le monde que nous avons vu depuis [1988].
# Probabilities: [0.1901744157075882, 0.4211994707584381, 0.3886260986328125]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La science est claire, le changement climatique aggrave les événements météorologiques extrêmes, y compris les tornades.
# Probabilities: [0.17513823509216309, 0.4391189217567444, 0.38574284315109253]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les vaches sont plus nocives pour le climat que toutes les voitures de la planète.
# Probabilities: [0.18646204471588135, 0.4275718033313751, 0.38596615195274353]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'activité des taches sur la surface de notre étoile a chuté à un nouveau plus bas.
# Probabilities: [0.18568359315395355, 0.4282779395580292, 0.38603851199150085]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le taux de réchauffement selon les données est beaucoup plus lent que les modèles utilisés par le GIEC.
# Probabilities: [0.1886042058467865, 0.42272546887397766, 0.38867032527923584]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La période de résidence atmosphérique du dioxyde de carbone est de cinq ans.
# Probabilities: [0.18895380198955536, 0.4246539771556854, 0.3863922357559204]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n’y a pas encore de preuves empiriques de leur affirmation selon laquelle les gaz à effet de serre provoquent même une augmentation des températures.
# Probabilities: [0.22224774956703186, 0.3927500247955322, 0.3850021958351135]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La NOAA a ajusté les températures passées pour paraître plus froides qu’elles ne l’étaient et les températures récentes pour paraître plus chaudes qu’elles ne l’étaient.
# Probabilities: [0.193162739276886, 0.41638338565826416, 0.39045387506484985]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ils allaient disparaître maintenant, mais maintenant ils établissent des records.
# Probabilities: [0.18593165278434753, 0.4271588921546936, 0.38690948486328125]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Des données non ajustées suggèrent que les températures en Australie n’ont augmenté que de 0,3 degré au cours du siècle dernier, et non du degré 1 habituellement revendiqué.
# Probabilities: [0.23397120833396912, 0.3803422451019287, 0.38568660616874695]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: [Les climatologues] disent que certains aspects du cas de l’ouragan Harvey suggèrent que le réchauffement climatique aggrave une mauvaise situation.
# Probabilities: [0.17253419756889343, 0.43990910053253174, 0.38755670189857483]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le GIEC, le Groupe d’experts intergouvernemental sur l’évolution du climat, qui est en quelque sorte la voix du consensus, concède qu’il n’y a pas eu d’augmentation des événements météorologiques extrêmes.
# Probabilities: [0.22424523532390594, 0.3881039619445801, 0.38765084743499756]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Selon les chiffres officiels, au cours des 10 dernières années, la température mondiale moyenne, la température mondiale moyenne, a légèrement diminué.
# Probabilities: [0.18540269136428833, 0.42714014649391174, 0.38745713233947754]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’action de Trump pourrait pousser la Terre au bord du gouffre, pour devenir comme Vénus, avec une température de deux cent cinquante degrés, et une pluie d’acide sulfurique.
# Probabilities: [0.17698214948177338, 0.43780237436294556, 0.3852154612541199]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Très probablement, le principal bouton de contrôle [sur le changement climatique] est les eaux océaniques et cet environnement dans lequel nous vivons.
# Probabilities: [0.18154668807983398, 0.43236321210861206, 0.38609007000923157]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le «réchauffement climatique» est un mythe – disons 80 graphiques de 58 articles scientifiques évalués par des pairs publiés en 2017.
# Probabilities: [0.18410257995128632, 0.4297563135623932, 0.3861410915851593]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ni le taux ni l'ampleur du réchauffement de surface rapporté à la fin du XXe siècle (1979-2000) ne se situaient en dehors de la variabilité naturelle normale.
# Probabilities: [0.2201208770275116, 0.3895289897918701, 0.3903501629829407]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Les projections prospectives de la cyclicité solaire impliquent que les prochaines décennies pourraient être marquées par un refroidissement global plutôt que par un réchauffement, malgré la poursuite des émissions de CO2.
# Probabilities: [0.17128361761569977, 0.4426138997077942, 0.38610249757766724]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le réchauffement climatique a cessé vers la fin du XXe siècle et a été suivi (depuis 1997) par 19 ans de température stable.
# Probabilities: [0.20105919241905212, 0.4074432849884033, 0.39149755239486694]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les augmentations de CO2 atmosphérique ont suivi les augmentations de température.
# Probabilities: [0.18428397178649902, 0.4285121262073517, 0.3872039020061493]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Par conséquent, les niveaux de CO2 ne pourraient pas avoir forcé les températures à augmenter.
# Probabilities: [0.23318710923194885, 0.38219574093818665, 0.3846170902252197]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: L’élévation du niveau de la mer ne s’accélère pas.
# Probabilities: [0.2215113639831543, 0.3913092017173767, 0.3871794641017914]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le niveau des mers locales et régionales continue de présenter une variabilité naturelle typique – dans certains endroits, il augmente et dans d’autres, il diminue.
# Probabilities: [0.17907221615314484, 0.4360271692276001, 0.3849005699157715]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La température n’augmente pas aussi vite que les modèles informatiques alarmistes l’avaient prédit.
# Probabilities: [0.2353411167860031, 0.38000208139419556, 0.3846568465232849]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Plus de 100% du réchauffement du siècle dernier est dû aux actions humaines.
# Probabilities: [0.19097110629081726, 0.4220079481601715, 0.387021005153656]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: 90 pour cent des récifs coralliens du monde disparaîtront dans les 35 prochaines années en raison du blanchissement des coraux induit par le réchauffement climatique, la pollution et le surdéveloppement.
# Probabilities: [0.1820501685142517, 0.4320424199104309, 0.3859074115753174]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le réchauffement n’est pas aussi important que les modèles informatiques du changement climatique l’ont prédit.
# Probabilities: [0.23202180862426758, 0.37985047698020935, 0.38812771439552307]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: El Niño a enregistré des records de températures mondiales, ce qui suggère que la hausse pourrait ne pas être due aux émissions anthropiques.
# Probabilities: [0.2106102705001831, 0.401136577129364, 0.3882531523704529]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’augmentation du dioxyde de carbone atmosphérique a contribué à augmenter la production alimentaire mondiale et à réduire la pauvreté.
# Probabilities: [0.18253357708454132, 0.4309200346469879, 0.3865463435649872]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’élévation du niveau de la mer, qui se produisait bien avant que les humains ne puissent être blâmés, ne s’est pas accélérée.
# Probabilities: [0.21723198890686035, 0.39609429240226746, 0.3866737484931946]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'élévation du niveau de la mer pourrait atteindre six ou sept pieds d'ici 2100.
# Probabilities: [0.18882355093955994, 0.42372700572013855, 0.3874495029449463]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le changement climatique n’aggrave pas les catastrophes naturelles.
# Probabilities: [0.2289639413356781, 0.38241758942604065, 0.3886185586452484]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: La quantité de terre que nous utilisons pour la viande - la plus grande utilisation de la terre par l'humanité - a diminué d'une superficie presque aussi grande que l'Alaska.
# Probabilities: [0.18264777958393097, 0.4305212199687958, 0.38683101534843445]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les émissions de carbone diminuent dans la plupart des pays riches et sont en baisse en Grande-Bretagne, en Allemagne et en France depuis le milieu des années 1970.
# Probabilities: [0.18500272929668427, 0.4284024238586426, 0.3865948021411896]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Prévenir de futures pandémies ne nécessite pas moins d’agriculture « industrielle ».
# Probabilities: [0.2205633670091629, 0.3910355865955353, 0.3884010910987854]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En conséquence, la moitié des personnes interrogées dans le monde l'année dernière ont déclaré qu'elles pensaient que le changement climatique ferait disparaître l'humanité.
# Probabilities: [0.18430694937705994, 0.4278298616409302, 0.3878632187843323]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Et en janvier, un enfant britannique sur cinq a déclaré aux sondeurs qu’ils faisaient des cauchemars sur le changement climatique.
# Probabilities: [0.18551048636436462, 0.4277057349681854, 0.3867837190628052]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Greenpeace n’a pas sauvé les baleines, passant de l’huile de baleine au pétrole et à l’huile de palme.
# Probabilities: [0.22732260823249817, 0.3884563744068146, 0.38422107696533203]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les scénarios de réchauffement planétaire les plus pessimistes devront peut-être être révisés à la hausse à la lumière d’une meilleure compréhension du rôle des nuages, ont déclaré des scientifiques.
# Probabilities: [0.18186981976032257, 0.4299250543117523, 0.3882051408290863]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Des données de modélisation récentes suggèrent que le climat est considérablement plus sensible aux émissions de carbone qu’on ne le pensait auparavant.
# Probabilities: [0.2177683562040329, 0.39277344942092896, 0.38945814967155457]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les précédents rapports du GIEC avaient tendance à supposer que les nuages auraient un impact neutre parce que les rétroactions de réchauffement et de refroidissement s’annuleraient mutuellement.
# Probabilities: [0.1798253059387207, 0.43381717801094055, 0.3863576054573059]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Catherine Senior, responsable de la compréhension du changement climatique au Met Office Hadley Centre, a déclaré que davantage d’études et de données étaient nécessaires pour comprendre pleinement le rôle des nuages et des aérosols.
# Probabilities: [0.17164194583892822, 0.443075954914093, 0.38528209924697876]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Réchauffement climatique contemporain placé dans un contexte géologique.
# Probabilities: [0.18692676723003387, 0.42594972252845764, 0.3871234655380249]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Une fonte extrême et des changements climatiques comme celui-ci ont libéré une pression sur le continent, permettant au sol de s’élever.
# Probabilities: [0.1788429319858551, 0.43472111225128174, 0.3864358961582184]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Nous les avons contactés pour leur demander plus de détails sur la taille du Sif.
# Probabilities: [0.1822827011346817, 0.431027352809906, 0.3866899907588959]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: De petites augmentations de la température moyenne se traduisent par de grandes augmentations du nombre de journées extrêmement chaudes, et ces journées chaudes ont un grand impact.
# Probabilities: [0.17570380866527557, 0.4393414855003357, 0.38495469093322754]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Lorsque les dirigeants de l’urgence pour l’action climatique ont contacté le gouvernement fédéral en avril, ils s’appuyaient sur des décennies de données montrant que les conditions d’incendie s’aggravent.
# Probabilities: [0.17816446721553802, 0.4352473318576813, 0.3865882158279419]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Au fur et à mesure que la température a augmenté, les scientifiques ont également la capacité de déterminer si des événements spécifiques sont liés au changement climatique.
# Probabilities: [0.18024547398090363, 0.4325805902481079, 0.38717398047447205]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ils peuvent maintenant modéliser la probabilité qu’un événement spécifique se produise dans des conditions historiques, par rapport aux températures record que nous connaissons.
# Probabilities: [0.17857736349105835, 0.43325790762901306, 0.3881646394729614]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Nous serons toujours confrontés à une chaleur extrême, mais à un niveau beaucoup plus gérable que si nous n’avions rien fait pour arrêter le changement climatique.
# Probabilities: [0.21257582306861877, 0.39623308181762695, 0.39119112491607666]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: S’il y avait des émissions de carbone, nous ne pourrions pas le voir parce que la plupart du carbone est noir.
# Probabilities: [0.2259574681520462, 0.38745105266571045, 0.3865915536880493]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le matériau des récifs est le carbonate de calcium, qui contient 44% de dioxyde de carbone.
# Probabilities: [0.17980161309242249, 0.4359893202781677, 0.3842090964317322]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les récifs ont besoin de dioxyde de carbone, c’est leur nourriture de base.
# Probabilities: [0.18015244603157043, 0.43515443801879883, 0.38469305634498596]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n’a jamais été démontré que les émissions humaines de dioxyde de carbone entraînent le réchauffement climatique.
# Probabilities: [0.2315109372138977, 0.38125380873680115, 0.38723522424697876]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Les modélisateurs supposent que le dioxyde de carbone est le moteur du changement climatique.
# Probabilities: [0.17487770318984985, 0.43944427371025085, 0.3856780529022217]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le changement climatique est normal et continuel.
# Probabilities: [0.19364072382450104, 0.41904953122138977, 0.3873097896575928]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le principal gaz à effet de serre est la vapeur d’eau [...]
# Probabilities: [0.18251687288284302, 0.432102769613266, 0.385380357503891]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le dioxyde de carbone est un gaz atmosphérique non condensable comme l'azote et l'oxygène.
# Probabilities: [0.18470796942710876, 0.4298980236053467, 0.38539400696754456]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Sans dioxyde de carbone, toute vie sur Terre mourrait.
# Probabilities: [0.18238192796707153, 0.43285682797431946, 0.38476112484931946]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les plantes ont besoin de près de trois fois la teneur en dioxyde de carbone de l’atmosphère d’aujourd’hui pour prospérer.
# Probabilities: [0.18483567237854004, 0.427895724773407, 0.3872685730457306]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pendant des décennies, les horticulteurs ont pompé du dioxyde de carbone dans les serres pour augmenter les rendements.
# Probabilities: [0.18033143877983093, 0.43476828932762146, 0.3849002420902252]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Dans le passé, le réchauffement n'a jamais été une menace pour la vie sur Terre.
# Probabilities: [0.23005817830562592, 0.3837014138698578, 0.3862403929233551]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Si nous réduisions de moitié la teneur en dioxyde de carbone atmosphérique d’aujourd’hui, toute vie mourrait.
# Probabilities: [0.18616101145744324, 0.4275650084018707, 0.38627398014068604]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Au cours de notre vie, il n’y a eu aucune corrélation entre les émissions de dioxyde de carbone et la température.
# Probabilities: [0.2235407680273056, 0.3902547359466553, 0.38620448112487793]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Après un réchauffement orbital naturel, la teneur en dioxyde de carbone atmosphérique augmente 800 ans plus tard.
# Probabilities: [0.18657535314559937, 0.42697688937187195, 0.3864477276802063]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Chacune des six grandes périodes glaciaires passées a commencé lorsque la teneur en dioxyde de carbone atmosphérique était beaucoup plus élevée qu'à l'heure actuelle.
# Probabilities: [0.18849003314971924, 0.4233193099498749, 0.3881906270980835]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pendant des décennies, la plupart des scientifiques ont considéré le changement climatique comme une perspective lointaine.
# Probabilities: [0.1853542923927307, 0.42747053503990173, 0.3871752917766571]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Un récent essai dans Scientific American a fait valoir que les scientifiques « ont tendance à sous-estimer la gravité des menaces et la rapidité avec laquelle elles pourraient se développer » et a déclaré que l’une des raisons était « le besoin perçu de consensus ».
# Probabilities: [0.17665286362171173, 0.4367641806602478, 0.38658297061920166]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: [Le rapport du GIEC de 1990 dit] que les calottes glaciaires de l’Antarctique étaient stables.
# Probabilities: [0.18107947707176208, 0.43130430579185486, 0.38761621713638306]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'ouragan Harvey a donné à Houston et à la région environnante une leçon de 125 milliards de dollars sur les coûts d'une mauvaise évaluation du potentiel d'inondations.
# Probabilities: [0.18125681579113007, 0.43325573205947876, 0.38548746705055237]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Au début des années 2000, les plates-formes de glace ont commencé à se désintégrer dans plusieurs parties de l'Antarctique, et les scientifiques ont réalisé que ce processus pourrait grandement accélérer la disparition des calottes glaciaires beaucoup plus grandes elles-mêmes.
# Probabilities: [0.17683984339237213, 0.43783578276634216, 0.3853243887424469]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La température moyenne du sol de la planète a augmenté d'environ 1,62F (0,9C)
# Probabilities: [0.18863600492477417, 0.42353880405426025, 0.3878251910209656]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les températures mondiales ont augmenté entre 0.23F (0.13C) et 0.34F (0.19C) par décennie.
# Probabilities: [0.1903025507926941, 0.4219299852848053, 0.3877674341201782]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Cependant, la tendance au réchauffement est plus lente que ne l’avaient prévu la plupart des modèles climatiques.
# Probabilities: [0.211219921708107, 0.39596399664878845, 0.39281612634658813]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En 1990, le Groupe d’experts intergouvernemental sur l’évolution du climat (GIEC) des Nations Unies a prédit que les températures augmenteraient de 0,54 ° F (0,3 ° C) par décennie.
# Probabilities: [0.18288105726242065, 0.42935308814048767, 0.38776588439941406]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Dans son cinquième rapport d’évaluation en 2013, le GIEC a estimé que les émissions humaines sont probablement responsables de plus de la moitié de l’augmentation observée de la température moyenne mondiale de 1951 à 2010.
# Probabilities: [0.1877364218235016, 0.423597127199173, 0.38866645097732544]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Mais cela signifie qu'une partie de la hausse vient d'ailleurs.
# Probabilities: [0.18623729050159454, 0.42476385831832886, 0.3889988362789154]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: À la fin des périodes glaciaires récentes, la concentration de dioxyde de carbone dans l’atmosphère n’a commencé à augmenter qu’après que les températures aient commencé à grimper.
# Probabilities: [0.21830324828624725, 0.39290669560432434, 0.3887901306152344]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Mais le plus grand gaz à effet de serre est de loin la vapeur d’eau, qui représente 95% du total.
# Probabilities: [0.18253223598003387, 0.43197140097618103, 0.3854963779449463]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le CO2 n’est pas puissant en ce sens, la seule chose qu’il fait dans le système est de rendre la planète plus verte.
# Probabilities: [0.21878527104854584, 0.3945292830467224, 0.38668540120124817]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il est pratiquement impossible d’obtenir des fonds pour le travail qui conteste le changement climatique par d’autres canaux [autres que les compagnies pétrolières]
# Probabilities: [0.2013351321220398, 0.40860000252723694, 0.3900648355484009]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'un des principaux sujets de discorde est l'existence de deux épisodes climatiques étranges connus sous le nom de la période chaude médiévale (MWP) et du petit âge glaciaire.
# Probabilities: [0.1782698929309845, 0.43583574891090393, 0.38589441776275635]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le MWP a duré d'environ 950 à 1250 après JC, et les enregistrements de température semblent montrer qu'il était encore plus chaud qu'aujourd'hui.
# Probabilities: [0.18895787000656128, 0.4216999113559723, 0.38934215903282166]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Mais la période a causé un mal de tête pour les scientifiques du climat parce qu'il n'y avait clairement pas de remontée du dioxyde de carbone qui pourrait expliquer un réchauffement aussi rapide.
# Probabilities: [0.21654322743415833, 0.39597269892692566, 0.38748404383659363]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En 1995, un scientifique du GIEC – Jonathan Overpeck – a écrit un courriel à un collègue affirmant « nous devons nous débarrasser de la période chaude médiévale ».
# Probabilities: [0.17701110243797302, 0.43540823459625244, 0.3875807523727417]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il est apparu plus tard que son créateur, le Dr Michael Mann, avait également épissé des ensembles de données – des anneaux d’arbres montrant des températures remontant à des centaines d’années, puis des lectures récentes du thermomètre pour les dernières décennies.
# Probabilities: [0.18174035847187042, 0.4325675070285797, 0.3856920897960663]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le GIEC n’inclut plus la carte « bâton de hockey » dans ses rapports.
# Probabilities: [0.2293763905763626, 0.385834276676178, 0.3847894072532654]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pourtant, une étude publiée cette semaine par le Centre Bjerknes pour la recherche climatique à Bergen, en Norvège, a révélé que le système climatique naturel peut changer brusquement, sans avoir besoin de forces extérieures.
# Probabilities: [0.1901463270187378, 0.4198620319366455, 0.3899916112422943]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Certains scientifiques pensent que l’activité solaire est plus susceptible d’influencer le climat d’aujourd’hui que le dioxyde de carbone, et le Dr Soon a compilé des données montrant que la température en Amérique, au Canada et au Mexique augmente et diminue en fonction de l’activité solaire.
# Probabilities: [0.17557057738304138, 0.4377984404563904, 0.38663095235824585]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La fonte des glaces a entraîné une élévation mondiale du niveau de la mer d'environ huit pouces depuis le début de la tenue de registres fiables en 1880.
# Probabilities: [0.18443800508975983, 0.42928415536880493, 0.38627785444259644]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Jusqu'à ce que les hausses de température commencent à ralentir après 1998 et restent relativement stables pendant une période de 15 ans.
# Probabilities: [0.18988116085529327, 0.42076295614242554, 0.38935586810112]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Dans un e-mail particulièrement accablant, le directeur du CRU, Phil Jones, a déclaré qu’il avait utilisé «Mike’s Nature» pour «cacher la baisse» des températures dans la seconde moitié du XXe siècle.
# Probabilities: [0.17892813682556152, 0.43396466970443726, 0.3871072828769684]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le groupe d’experts a été contraint de retirer une déclaration dans son rapport de 2007 selon laquelle tous les glaciers de l’Himalaya pourraient fondre entièrement d’ici 2035.
# Probabilities: [0.1786077469587326, 0.43547070026397705, 0.38592150807380676]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le chiffre traditionnellement cité qui suggère que 97% des climatologues sont d’accord pour dire que le réchauffement climatique est d’origine humaine a également été trouvé défectueux.
# Probabilities: [0.1824399083852768, 0.4312538206577301, 0.3863062262535095]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les climato-sceptiques soutiennent que les enregistrements de température ont été ajustés ces dernières années pour rendre le passé plus frais et le présent plus chaud, bien que le Carbon Brief ait montré que la NOAA a effectivement fait la différence.
# Probabilities: [0.17956846952438354, 0.4333096444606781, 0.38712188601493835]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Lorsque l'équipement de mesure vieillit et doit être remplacé, il nécessite souvent un nouvel étalonnage.
# Probabilities: [0.18232178688049316, 0.4320862889289856, 0.38559192419052124]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Un réseau mondial de 500 scientifiques et professionnels a préparé ce message urgent.
# Probabilities: [0.18685002624988556, 0.4270493984222412, 0.3861006498336792]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le petit âge glaciaire a pris fin en 1850.
# Probabilities: [0.19811943173408508, 0.4135562777519226, 0.3883242607116699]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Seuls très peu d’articles examinés par des pairs vont même jusqu’à dire que le réchauffement récent est principalement anthropique.
# Probabilities: [0.1841409057378769, 0.4296003580093384, 0.38625872135162354]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En outre, [les modèles climatiques] ignorent le fait que l’enrichissement de l’atmosphère en CO2 est bénéfique.
# Probabilities: [0.17965660989284515, 0.43282243609428406, 0.387520968914032]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n’y a aucune preuve statistique que le réchauffement climatique s’intensifie [...] inondations.
# Probabilities: [0.2303832620382309, 0.38086438179016113, 0.3887523114681244]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Il n’y a aucune preuve statistique que le réchauffement climatique s’intensifie [...] les sécheresses.
# Probabilities: [0.23010270297527313, 0.3811754286289215, 0.38872185349464417]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Par exemple, les éoliennes tuent les oiseaux et les insectes, et les plantations d’huile de palme détruisent la biodiversité des forêts tropicales.
# Probabilities: [0.1741960495710373, 0.44187015295028687, 0.38393381237983704]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les données ne montrent qu'un léger réchauffement, principalement la nuit et l'hiver.
# Probabilities: [0.23322667181491852, 0.3805333375930786, 0.3862399458885193]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Il n'y a pas eu d'augmentation systématique de la fréquence des événements météorologiques extrêmes.
# Probabilities: [0.2296905815601349, 0.38433748483657837, 0.38597196340560913]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Découvrons-le en comparant les températures réelles depuis 1979 avec ce que les 32 familles de modèles climatiques utilisées dans le dernier rapport de l’ONU sur la science du climat prédisaient.
# Probabilities: [0.18290099501609802, 0.42990410327911377, 0.3871949017047882]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les thermomètres moyens montrent deux périodes de réchauffement depuis 1900: un demi-degré de causes naturelles dans la première moitié du 20ème siècle, avant qu'il y ait une augmentation du dioxyde de carbone industriel qui était suffisant pour le produire, et un autre demi-degré dans le dernier quart du siècle.
# Probabilities: [0.18596312403678894, 0.42625313997268677, 0.3877837061882019]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le premier ajustement a modifié la façon dont la température de la surface de l’océan est calculée, en remplaçant les données satellitaires par des bouées dérivantes et des températures dans la prise d’eau des navires.
# Probabilities: [0.17389167845249176, 0.4405997097492218, 0.38550856709480286]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Mais chaque ajustement en série a eu tendance à rendre les premières années plus froides, ce qui augmente la tendance au réchauffement.
# Probabilities: [0.18523579835891724, 0.4275650084018707, 0.38719919323921204]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les abris dans les pays les plus pauvres ne sont pas repeints aussi souvent, et les stations plus sombres absorbent une plus grande partie de l’énergie solaire.
# Probabilities: [0.21172408759593964, 0.40007057785987854, 0.3882053792476654]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les températures ont été de 6 à 10 ° C au-dessus de la normale dans la majeure partie de la France, de l'Allemagne et du nord de l'Espagne au cours des derniers jours du mois, selon C3S.
# Probabilities: [0.18467681109905243, 0.42820510268211365, 0.38711807131767273]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'évaluation rapide des températures moyennes en France entre le 26 et le 28 juin a montré une augmentation 'substantielle' de la probabilité que la vague de chaleur se produise en raison du réchauffement climatique causé par l'homme, ont déclaré des experts du groupe World Weather Attribution.
# Probabilities: [0.17886048555374146, 0.4342740476131439, 0.38686540722846985]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les vagues de chaleur se produisent dans n'importe quel climat, mais nous savons que les vagues de chaleur deviennent beaucoup plus probables en raison du changement climatique.
# Probabilities: [0.178702712059021, 0.4347282350063324, 0.3865690529346466]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Alors que les membres des médias peuvent acquiescer à de telles affirmations [sur les changements dans les conditions météorologiques extrêmes], les preuves décrivent une histoire différente.
# Probabilities: [0.17277748882770538, 0.44240590929985046, 0.38481661677360535]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ils ont conclu que les tendances à la hausse des dommages climatiques étaient principalement dues à l’augmentation de la population et de l’activité économique sur le chemin des tempêtes, qu’il n’était actuellement pas possible de déterminer la part des dommages attribuables aux gaz à effet de serre et qu’ils ne s’attendaient pas à ce que cette situation change dans un proche avenir.
# Probabilities: [0.21448825299739838, 0.39693617820739746, 0.38857561349868774]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: À l’échelle mondiale, il n’existe aucune preuve claire des tendances et des tendances des événements extrêmes tels que les sécheresses, les ouragans et les inondations.
# Probabilities: [0.21225214004516602, 0.4008965492248535, 0.3868512213230133]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n’y a pas de tendance aux inondations liées aux ouragans aux États-Unis.
# Probabilities: [0.22931186854839325, 0.38678932189941406, 0.3838987648487091]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n'y a pas non plus de preuve d'une augmentation des inondations à l'échelle mondiale.
# Probabilities: [0.23550711572170258, 0.38114818930625916, 0.38334470987319946]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Depuis 1965, plus de régions des États-Unis ont connu une diminution des inondations que n’en ont connu une augmentation.
# Probabilities: [0.18503323197364807, 0.42697814106941223, 0.3879886269569397]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Et de 1940 à aujourd'hui, les dégâts causés par les inondations en pourcentage du PIB sont passés d'environ 0,2 % à moins de 0,05 % par an.
# Probabilities: [0.21973395347595215, 0.3909142315387726, 0.38935181498527527]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En fin de compte, il n’y a pas de lien solide entre le changement climatique et les principaux indicateurs de conditions météorologiques extrêmes.
# Probabilities: [0.22803623974323273, 0.3828822672367096, 0.3890814483165741]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Cela nous oblige à travailler pour éviter les possibilités catastrophiques plutôt que de regarder les probabilités, car apprendre des erreurs n’est pas une option quand il s’agit de risques existentiels.
# Probabilities: [0.20652616024017334, 0.40445297956466675, 0.3890208899974823]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Dans cet esprit, ils proposent un «scénario 2050» plausible et terrifiant dans lequel l’humanité pourrait faire face à un effondrement irréversible en seulement trois décennies.
# Probabilities: [0.18071378767490387, 0.43131378293037415, 0.3879723846912384]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Leur analyse calcule le risque existentiel lié au climat pour la sécurité de la Terre à travers un scénario fixé 30 ans dans le futur.
# Probabilities: [0.18591837584972382, 0.42690613865852356, 0.38717544078826904]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’Amérique du Nord subit des phénomènes météorologiques extrêmes, notamment des incendies de forêt, des sécheresses et des vagues de chaleur.
# Probabilities: [0.17663230001926422, 0.4380050599575043, 0.3853626847267151]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les moussons en Chine échouent, les grands fleuves d'Asie s'assèchent pratiquement et les précipitations en Amérique centrale diminuent de moitié.
# Probabilities: [0.18039043247699738, 0.4340119957923889, 0.3855976462364197]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les répercussions affectent la sécurité nationale, car l’ampleur des défis en jeu, tels que les épidémies de pandémie, est écrasante.
# Probabilities: [0.17353682219982147, 0.4414232671260834, 0.38503992557525635]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les conflits armés sur les ressources peuvent devenir une réalité et avoir le potentiel de dégénérer en guerre nucléaire.
# Probabilities: [0.1798611581325531, 0.43394553661346436, 0.38619327545166016]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En 2050, il y a un consensus scientifique sur le fait que nous avons atteint le point de basculement des calottes glaciaires au Groenland et dans l’Antarctique occidental.
# Probabilities: [0.18218949437141418, 0.4310440123081207, 0.3867665231227875]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Comme d'innombrables autres organismes, nous nous déplaçons et nous adaptons lorsque l'environnement change.
# Probabilities: [0.1812180131673813, 0.4320065379142761, 0.3867754340171814]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Lorsque 3% du total des émissions annuelles mondiales de dioxyde de carbone proviennent de l’homme et que l’Australie produit 1,3% de ces 3%, alors aucune réduction des émissions n’aura d’effet sur le climat mondial.
# Probabilities: [0.2022477239370346, 0.4099527895450592, 0.38779953122138977]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Si nous réduisons de moitié la teneur en dioxyde de carbone de l'atmosphère, toute vie meurt.
# Probabilities: [0.18346740305423737, 0.430618554353714, 0.3859140872955322]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pendant des milliers de millions d'années, la Terre a changé, avec des cycles - et des événements ponctuels tels qu'un impact d'astéroïde, un super-volcan ou une explosion de supernova.
# Probabilities: [0.17709305882453918, 0.43771177530288696, 0.38519516587257385]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La quantité d’énergie utilisée pour construire des installations solaires et éoliennes est supérieure à ce qu’elles produisent dans leur vie professionnelle.
# Probabilities: [0.1823551505804062, 0.43219876289367676, 0.3854460120201111]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: 'Dès que les énergies renouvelables ont été introduites dans le réseau, les prix de l'électricité ont augmenté et la livraison est devenue peu fiable.
# Probabilities: [0.19188617169857025, 0.4203108549118042, 0.38780301809310913]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les énergies renouvelables, telles que les éoliennes, sont désastreuses pour l'environnement car elles polluent une vaste zone terrestre, coupent et coupent les oiseaux et les chauves-souris, tuent les insectes qui sont de la nourriture pour les oiseaux, créent des problèmes de santé pour les humains qui vivent à des kilomètres d'eux, laissent des toxines autour du site de l'éolienne et spolient le paysage.
# Probabilities: [0.17331120371818542, 0.4434925317764282, 0.38319632411003113]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: On nous a également dit que le problème n’est certainement pas une planète vieille de milliards d’années qui traverse des cycles où la température pourrait fluctuer un peu.
# Probabilities: [0.19972209632396698, 0.41011881828308105, 0.39015913009643555]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il n'y avait pas de calotte glaciaire couvrant le Groenland ou l'Antarctique occidental, et une grande partie de la calotte glaciaire de l'Antarctique oriental avait disparu.
# Probabilities: [0.2182713747024536, 0.39662936329841614, 0.38509923219680786]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Une étude qui démystifie totalement tout le concept de réchauffement climatique causé par l’homme.
# Probabilities: [0.18588967621326447, 0.42672935128211975, 0.3873809576034546]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Nous ne pouvons rien faire pour arrêter les cycles climatiques naturels de la Terre.
# Probabilities: [0.22909431159496307, 0.3859226703643799, 0.38498300313949585]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les «enregistrements thermiques» du changement climatique sont une énorme manipulation de données.
# Probabilities: [0.17944729328155518, 0.4357941746711731, 0.3847585618495941]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L’idée que le changement climatique produit des records de chaleur à travers la Terre est l’une des manipulations les plus flagrantes des données dans le débat absurde sur le réchauffement climatique.
# Probabilities: [0.18099580705165863, 0.4317137897014618, 0.3872903883457184]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le 7 février, plusieurs grands journaux ont publié des articles sur la déclaration de la NASA et de la NOAA selon laquelle les cinq dernières années ont été les plus chaudes jamais enregistrées.
# Probabilities: [0.1836938112974167, 0.43016287684440613, 0.3861432373523712]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les données météorologiques réelles des 100 dernières années ne montrent aucune corrélation entre la hausse des niveaux de dioxyde de carbone et les températures locales.
# Probabilities: [0.2197377234697342, 0.39429083466529846, 0.38597139716148376]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: À mesure que le temps passe et que les émissions de combustibles fossiles augmentent, le nombre de records devrait augmenter et les records devraient diminuer.
# ...
# Probabilities: [0.18196889758110046, 0.4318374693393707, 0.38619354367256165]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Environ 60% du réchauffement observé de 1970 à 2000 a été très probablement causé par le cycle climatique naturel de 60 ans au cours de sa phase de réchauffement.
# Probabilities: [0.18953080475330353, 0.42193934321403503, 0.3885299265384674]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il semble y avoir des preuves d'un lien entre l'activité solaire et les niveaux d'eau.
# Probabilities: [0.18231992423534393, 0.4310268461704254, 0.38665321469306946]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Cependant, des comparaisons plus directes entre l'activité solaire et la température mondiale montrent que, lorsque le soleil se réchauffe ou se refroidit, le climat de la Terre le suit avec un décalage de 10 ans - probablement en raison de l'effet d'amortissement de l'océan.
# Probabilities: [0.1758788377046585, 0.43816688656806946, 0.38595423102378845]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: On a également découvert que la corrélation entre l’activité solaire et les températures mondiales a pris fin vers 1975, d’où le réchauffement récent doit avoir une autre cause que les variations solaires.
# Probabilities: [0.1799612194299698, 0.432881236076355, 0.3871576189994812]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Un article sud-africain a trouvé un cycle de 21 ans synchrone avec le cycle solaire (Alexander 2007).
# Probabilities: [0.1868329793214798, 0.4262758493423462, 0.3868911564350128]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Certaines des régions dans lesquelles GRACE revendique une perte de glace en Antarctique de l'Est sont en moyenne plus froides que -30°C pendant l'été, et ne dépassent jamais le point de congélation.
# Probabilities: [0.2065594345331192, 0.4057741165161133, 0.38766640424728394]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Contrairement au simple exemple de rétroaction positive que nous avons appris à l’école secondaire, l’augmentation de chaque tour de rétroaction devient de plus en plus petite, dans le cas de l’effet de serre accru.
# Probabilities: [0.17749427258968353, 0.4374997615814209, 0.38500601053237915]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: En conséquence, les niveaux de CO2 autour de 1.000 à 2.300 ppm étaient en fait assez bas pour favoriser la glaciation dans le continent sud du Gondwana.
# Probabilities: [0.17971345782279968, 0.434486985206604, 0.3857995867729187]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Étant donné que l’altération des roches réduit le CO2 atmosphérique, cela renforce à nouveau le fait scientifique que le CO2 est un puissant moteur du climat.
# Probabilities: [0.1780484914779663, 0.4365729093551636, 0.38537856936454773]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: De toute évidence, d’autres facteurs que le carbone atmosphérique influencent les températures de la Terre et le réchauffement climatique.
# Probabilities: [0.18153777718544006, 0.43313902616500854, 0.385323166847229]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Hocker prétend que son modèle montre que la tendance à la hausse à long terme du CO2 s’explique par la température, alors que ses méthodes ont effectivement éliminé la tendance à long terme.
# Probabilities: [0.17597122490406036, 0.43760958313941956, 0.38641923666000366]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Des milliers d'atolls coralliens se sont 'noyés' dans le passé lorsqu'ils étaient incapables de se développer assez vite pour maintenir une présence au niveau de la mer.
# Probabilities: [0.18263238668441772, 0.4313124418258667, 0.38605523109436035]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il existe de nombreuses preuves qui montrent clairement que l'augmentation du CO2 atmosphérique est causée par l'homme.
# Probabilities: [0.17366714775562286, 0.43998852372169495, 0.386344313621521]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le plus clair d'entre eux est la comptabilité simple - les humains émettent du CO2 à un rythme deux fois plus rapide que l'augmentation atmosphérique (les puits naturels absorbent l'autre moitié).
# Probabilities: [0.18136611580848694, 0.432407945394516, 0.3862259089946747]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il ne fait aucun doute que l’augmentation du CO2 est d’origine humaine.
# Probabilities: [0.22302749752998352, 0.38858264684677124, 0.3883898854255676]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Cette augmentation du CO2 atmosphérique que nous observons est un produit de l'augmentation de la température, et non l'inverse, ce qui signifie que c'est un produit de la variation naturelle.
# Probabilities: [0.20535486936569214, 0.40533390641212463, 0.3893112242221832]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: '...il n'y a pas eu d'augmentation de la température moyenne de surface au cours des 16 dernières années' (Judith Curry et David Rose)
# Probabilities: [0.23188944160938263, 0.3841109871864319, 0.38399961590766907]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les modèles et les observations directes montrent que les CFC ne contribuent qu'à une fraction du réchauffement fourni par d'autres gaz à effet de serre.
# Probabilities: [0.2111138254404068, 0.3990265130996704, 0.389859676361084]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Cela augmente la confiance dans d'autres recherches évaluées par des pairs qui prévoient une élévation du niveau de la mer de 80 cm à 2 mètres d'ici 2100.
# Probabilities: [0.18288445472717285, 0.43120917677879333, 0.38590630888938904]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: « Un autre mythe du réchauffement climatique s’effondre.
# Probabilities: [0.18957370519638062, 0.4217114746570587, 0.38871482014656067]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pas de réchauffement depuis au moins 1995, pas de fonte des glaciers et maintenant pas d’élévation du niveau de la mer.
# Probabilities: [0.2298450917005539, 0.3848270773887634, 0.38532784581184387]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: L’affirmation selon laquelle 2,2 emplois conventionnels sont détruits pour chaque nouvel emploi créé dans l’industrie de l’énergie alternative est basée sur une étude qui repose sur des chiffres incorrects, des dates sélectionnées, une théorie erronée, une méthodologie défectueuse et est réfutée par des exemples concrets.
# Probabilities: [0.1788957417011261, 0.43586960434913635, 0.38523462414741516]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pour chaque emploi dans les énergies renouvelables que l’État parvient à financer, l’expérience de l’Espagne... révèle avec une grande confiance, par deux méthodes différentes, que les États-Unis devraient s’attendre à une perte d’au moins 2,2 emplois en moyenne.
# Probabilities: [0.1809455305337906, 0.43234917521476746, 0.38670530915260315]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La poursuite des émissions de gaz à effet de serre à des taux actuels ou supérieurs entraînerait un réchauffement supplémentaire et induirait de nombreux changements dans le système climatique mondial au cours du XXIe siècle qui seraient très probablement plus importants que ceux observés au cours du XXe siècle.
# Probabilities: [0.18339063227176666, 0.4290563762187958, 0.38755297660827637]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: C’est donc un gouvernement qui propose de mettre en danger notre industrie manufacturière, de pénaliser les familles en difficulté, d’aggraver la situation difficile de millions de ménages en Australie.
# Probabilities: [0.17168870568275452, 0.44357216358184814, 0.38473907113075256]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Quatrième rapport d'évaluation (AR4), dans lequel la plage probable est de 2,0 °C à 4,5 °C, avec une meilleure estimation de 3,0 °C » (Pat Michaels)
# Probabilities: [0.17963218688964844, 0.43247953057289124, 0.3878883421421051]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: De multiples preuves indiquent que la perte de glace du Groenland s'accélère et contribuera à l'élévation du niveau de la mer de l'ordre de quelques mètres au cours des prochains siècles.
# Probabilities: [0.1708454042673111, 0.4439813196659088, 0.3851732909679413]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: C’était aussi le cas l’année dernière, alors que les années précédentes dans la période d’analyse de l’IMD (1958-2010) ne montrent presque jamais des températures de la saison de fonte de l’Arctique aussi froides (Frank Lansner)
# Probabilities: [0.2100512683391571, 0.400285542011261, 0.3896632492542267]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Cependant, un seul scientifique, le Dr Ben Santer du Lawrence Livermore National Laboratory, a réécrit le projet à la demande du GIEC, supprimant les cinq déclarations, les remplaçant par une seule déclaration selon laquelle une influence humaine sur le climat mondial était maintenant perceptible, et apportant quelque 200 amendements consécutifs.
# Probabilities: [0.18138930201530457, 0.43108928203582764, 0.3875214457511902]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Une estimation généreuse de l’énergie générée par les satellites est environ 1 million de fois trop petite pour provoquer le réchauffement climatique.
# Probabilities: [0.18197715282440186, 0.4313599169254303, 0.38666290044784546]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'histoire du réchauffement climatique coïncide complètement avec l'histoire des satellites artificiels et l'utilisation des micro-ondes de l'espace.
# Probabilities: [0.181452214717865, 0.4317317008972168, 0.386816143989563]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: L'envoi de micro-ondes oscillantes à partir d'une antenne à l'intérieur d'un vide à travers un champ électromagnétique à travers un matériau diélectrique, tel que l'eau, crée un chauffage par radiofréquence au niveau moléculaire.
# Probabilities: [0.17884904146194458, 0.4368837773799896, 0.384267121553421]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le quatrième rapport d’évaluation du GIEC, 2007, porte en trois endroits un graphique dans lequel l’ensemble de données mondial sur les anomalies de température de surface moyenne du Centre Hadley de 1850 à 2005 est affiché avec quatre lignes de tendance choisies arbitrairement superposées.
# Probabilities: [0.18309029936790466, 0.43106815218925476, 0.3858415484428406]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Il y a des preuves anecdotiques et autres suggérant des fusions similaires de 1938 à 1943 et à d'autres occasions.
# Probabilities: [0.18345676362514496, 0.43166980147361755, 0.38487350940704346]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les catastrophes coûtent plus cher que jamais, mais pas à cause du changement climatique (Roger Pielke Jr.)
# Probabilities: [0.2237035185098648, 0.38843604922294617, 0.387860506772995]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les capteurs satellites montrent moins de réchauffement dans la basse troposphère (environ 10 000 pieds au-dessus de la surface de la Terre) que ce qui est rapporté par les lectures de température de surface.
# Probabilities: [0.18488305807113647, 0.42802828550338745, 0.3870886266231537]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La théorie du réchauffement climatique soutient que l’une des empreintes du réchauffement climatique induit par l’homme est un réchauffement plus rapide dans la basse troposphère qu’à la surface.
# Probabilities: [0.18062953650951385, 0.4325457811355591, 0.38682466745376587]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: À l’époque, on ne pouvait pas voir de l’autre côté de la rue pour toutes les émissions de carbone et les conneries qui sortaient des cheminées. »
# Probabilities: [0.22455154359340668, 0.3903411328792572, 0.3851073384284973]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La reconstruction de la température millénaire de Ljungqvist était très similaire à celle de Moberg et al.
# Probabilities: [0.18310807645320892, 0.43071070313453674, 0.38618117570877075]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Ce que je peux commenter, c’est cette prédiction du Dr Hansen : « La West Side Highway [qui longe l’Hudson River] sera sous l’eau. »
# Probabilities: [0.16891741752624512, 0.4453452229499817, 0.3857373595237732]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Le CO2 représente 80% du forçage des gaz à effet de serre sans condensation.
# Probabilities: [0.184503972530365, 0.430083304643631, 0.3854127526283264]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La couverture nuageuse dans les modèles est mal traitée et prédite de manière inexacte.
# Probabilities: [0.18319794535636902, 0.43125060200691223, 0.38555145263671875]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Pourtant, les nuages reflètent environ soixante-quinze watts par mètre carré.
# Probabilities: [0.18393078446388245, 0.43030983209609985, 0.3857593834400177]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Étant donné qu'un doublement du dioxyde de carbone modifierait le flux de chaleur de surface de seulement deux watts par mètre carré, il est évident qu'un petit changement dans la couverture nuageuse peut fortement affecter la réponse au dioxyde de carbone.
# Probabilities: [0.17797188460826874, 0.43655434250831604, 0.3854738473892212]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: La Grande Barrière de Corail est en pleine effervescence.
# Probabilities: [0.18281926214694977, 0.4316742420196533, 0.3855065703392029]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Environ 60% du réchauffement observé de 1970 à 2000 a été très probablement causé par ce cycle climatique naturel de 60 ans au cours de sa phase de réchauffement.
# Probabilities: [0.18961036205291748, 0.4218527674674988, 0.38853681087493896]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Les sceptiques espèrent que le modèle thermique alternatif de Postma mènera à la naissance d'une nouvelle climatologie, qui suit réellement les lois de la physique et des techniques de modélisation physique.
# Probabilities: [0.1752540022134781, 0.4392440915107727, 0.3855019211769104]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: « Il existe d’autres causes possibles de changement climatique qui pourraient être associées à l’activité solaire ou liées aux variations de la température du noyau liquide de la Terre, qui est d’environ 5 400 degrés Celsius.
# Probabilities: [0.17934764921665192, 0.4335636794567108, 0.38708871603012085]
# Predicted Label: REFUTES
# predicted_label: REFUTES
# Claim: Nous n'avons pas besoin d'un flux de chaleur élevé - juste une température élevée pour que le cœur affecte le climat de surface.
# Probabilities: [0.23047371208667755, 0.3844546675682068, 0.38507160544395447]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Claim: Au cours de la dernière décennie, les vagues de chaleur sont cinq fois plus probables que s’il n’y avait pas eu de réchauffement climatique.
# Probabilities: [0.2253035008907318, 0.3855074346065521, 0.3891890347003937]
# Predicted Label: UNDECIDED
# predicted_label: UNDECIDED
# Accuracy: 0.1738
# Precision (weighted): 0.1473
# Recall (weighted): 0.1738
# F1 Score (weighted): 0.0837
# d:\anaconda3\envs\climate-fake-news-detection\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(model.config.num_labels)  # Should print 3 if you're predicting 3 classes
# Out:
# 3
